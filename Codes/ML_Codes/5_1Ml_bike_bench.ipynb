# %%
#Import dependencies

import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
# Load the X_train, test; y_train, test files

from google.colab import drive
drive.mount('/content/drive')


X_train = pd.read_pickle('/content/drive/MyDrive/final/X_train.pkl')
X_test = pd.read_pickle('/content/drive/MyDrive/final/X_test.pkl')
y_train = pd.read_pickle('/content/drive/MyDrive/final/y_train.pkl')
y_test = pd.read_pickle('/content/drive/MyDrive/final/y_test.pkl')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## LinearRegression

# %%
# train model

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Evaluation
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error on test set: {mae:.2f} minutes")
# Out:
# Mean Absolute Error on test set: 7.68 minutes

# %%
# MAE (already used)
mae = mean_absolute_error(y_test, y_pred)

# RMSE (Root Mean Squared Error)
rmse = mean_squared_error(y_test, y_pred)

# R² Score (coefficient of determination)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f} minutes")
print(f"RMSE: {rmse:.2f} minutes")
print(f"R² Score: {r2:.4f}")

#MAE shows average error in the same units.
#RMSE penalizes large errors more heavily.
#R² Score shows how much variance in duration is explained by the model
#   (1.0 is perfect, 0.0 means "as good as mean", negative means worse).
# Out:
# MAE: 7.68 minutes
# RMSE: 102.57 minutes
# R² Score: 0.0091

# %%
# Plot
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.3)
plt.xlabel("Actual Duration (min)")
plt.ylabel("Predicted Duration (min)")
plt.title("Actual vs Predicted Duration")
plt.plot([0, 120], [0, 120], 'r--', linewidth=2)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ridge Regression

# %%
# train model

model2 = Ridge(alpha=1.0)
model2.fit(X_train, y_train)
# Out:
# Ridge()

# %%
# Evaluation
y_pred = model2.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error on test set: {mae:.2f} minutes")
# Out:
# Mean Absolute Error on test set: 7.68 minutes

# %%
# MAE (already used)
mae = mean_absolute_error(y_test, y_pred)

# RMSE (Root Mean Squared Error)
rmse = mean_squared_error(y_test, y_pred)

# R² Score (coefficient of determination)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f} minutes")
print(f"RMSE: {rmse:.2f} minutes")
print(f"R² Score: {r2:.4f}")

#MAE shows average error in the same units.
#RMSE penalizes large errors more heavily.
#R² Score shows how much variance in duration is explained by the model
#   (1.0 is perfect, 0.0 means "as good as mean", negative means worse).
# Out:
# MAE: 7.68 minutes
# RMSE: 102.57 minutes
# R² Score: 0.0091

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.3)
plt.xlabel("Actual Duration (min)")
plt.ylabel("Predicted Duration (min)")
plt.title("Actual vs Predicted Duration")
plt.plot([0, 120], [0, 120], 'r--', linewidth=2)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Lasso Regression

# %%
# train model

model3 = Lasso(alpha=0.1)
model3.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
# Evaluation

y_pred = model3.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error on test set: {mae:.2f} minutes")
# Out:
# Mean Absolute Error on test set: 7.68 minutes

# %%
# MAE (already used)
mae = mean_absolute_error(y_test, y_pred)

# RMSE (Root Mean Squared Error)
rmse = mean_squared_error(y_test, y_pred)

# R² Score (coefficient of determination)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f} minutes")
print(f"RMSE: {rmse:.2f} minutes")
print(f"R² Score: {r2:.4f}")

#MAE shows average error in the same units.
#RMSE penalizes large errors more heavily.
#R² Score shows how much variance in duration is explained by the model
#   (1.0 is perfect, 0.0 means "as good as mean", negative means worse).
# Out:
# MAE: 7.68 minutes
# RMSE: 102.60 minutes
# R² Score: 0.0088

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.3)
plt.xlabel("Actual Duration (min)")
plt.ylabel("Predicted Duration (min)")
plt.title("Actual vs Predicted Duration")
plt.plot([0, 120], [0, 120], 'r--', linewidth=2)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#    ## Decision Tree Regressor

# %%
# train model

model4 = DecisionTreeRegressor(max_depth=10)
model4.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=10)

# %%
# Evaluation

y_pred = model4.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error on test set: {mae:.2f} minutes")
# Out:
# Mean Absolute Error on test set: 7.49 minutes

# %%
# MAE (already used)
mae = mean_absolute_error(y_test, y_pred)

# RMSE (Root Mean Squared Error)
rmse = mean_squared_error(y_test, y_pred)

# R² Score (coefficient of determination)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f} minutes")
print(f"RMSE: {rmse:.2f} minutes")
print(f"R² Score: {r2:.4f}")

#MAE shows average error in the same units.
#RMSE penalizes large errors more heavily.
#R² Score shows how much variance in duration is explained by the model
#   (1.0 is perfect, 0.0 means "as good as mean", negative means worse).
# Out:
# MAE: 7.49 minutes
# RMSE: 98.83 minutes
# R² Score: 0.0453

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.3)
plt.xlabel("Actual Duration (min)")
plt.ylabel("Predicted Duration (min)")
plt.title("Actual vs Predicted Duration")
plt.plot([0, 120], [0, 120], 'r--', linewidth=2)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#    ## Random ForestRegressor

# %%
# train model

#model5 = RandomForestRegressor(n_estimators=100, max_samples=0.5, random_state=42)
#model5.fit(X_train, y_train)

#model5 = RandomForestRegressor(n_estimators=50, max_samples=0.3, random_state=10)
#model5.fit(X_train, y_train)

model5 = RandomForestRegressor(n_estimators=50, max_samples=0.3, min_samples_leaf=10, random_state=42)
model5.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_samples=0.3, min_samples_leaf=10, n_estimators=50,
#                       random_state=42)

# %%
# Evaluation

y_pred = model5.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error on test set: {mae:.2f} minutes")
# Out:
# Mean Absolute Error on test set: 7.04 minutes

# %%
# MAE (already used)
mae = mean_absolute_error(y_test, y_pred)

# RMSE (Root Mean Squared Error)
rmse = mean_squared_error(y_test, y_pred)

# R² Score (coefficient of determination)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f} minutes")
print(f"RMSE: {rmse:.2f} minutes")
print(f"R² Score: {r2:.4f}")

#MAE shows average error in the same units.
#RMSE penalizes large errors more heavily.
#R² Score shows how much variance in duration is explained by the model
#   (1.0 is perfect, 0.0 means "as good as mean", negative means worse).
# Out:
# MAE: 7.04 minutes
# RMSE: 92.49 minutes
# R² Score: 0.1065

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.3)
plt.xlabel("Actual Duration (min)")
plt.ylabel("Predicted Duration (min)")
plt.title("Actual vs Predicted Duration")
plt.plot([0, 120], [0, 120], 'r--', linewidth=2)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#    ## Gradient Boosting Regressor

# %%
# train model


model6 = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
model6.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
# Evaluation

y_pred = model6.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error on test set: {mae:.2f} minutes")
# Out:
# Mean Absolute Error on test set: 7.52 minutes

# %%
# MAE (already used)
mae = mean_absolute_error(y_test, y_pred)

# RMSE (Root Mean Squared Error)
rmse = mean_squared_error(y_test, y_pred)

# R² Score (coefficient of determination)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f} minutes")
print(f"RMSE: {rmse:.2f} minutes")
print(f"R² Score: {r2:.4f}")

#MAE shows average error in the same units.
#RMSE penalizes large errors more heavily.
#R² Score shows how much variance in duration is explained by the model
#   (1.0 is perfect, 0.0 means "as good as mean", negative means worse).
# Out:
# MAE: 7.52 minutes
# RMSE: 99.29 minutes
# R² Score: 0.0408

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.3)
plt.xlabel("Actual Duration (min)")
plt.ylabel("Predicted Duration (min)")
plt.title("Actual vs Predicted Duration")
plt.plot([0, 120], [0, 120], 'r--', linewidth=2)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##     LGBM Regressor

# %%
# train model


model8 = LGBMRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
model8.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.201303 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 352
# [LightGBM] [Info] Number of data points in the train set: 10778328, number of used features: 5
# [LightGBM] [Info] Start training from score 20.934186
# LGBMRegressor(random_state=42)

# %%
# Evaluation

y_pred = model8.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error on test set: {mae:.2f} minutes")
# Out:
# Mean Absolute Error on test set: 7.46 minutes

# %%
# MAE (already used)
mae = mean_absolute_error(y_test, y_pred)

# RMSE (Root Mean Squared Error)
rmse = mean_squared_error(y_test, y_pred)

# R² Score (coefficient of determination)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f} minutes")
print(f"RMSE: {rmse:.2f} minutes")
print(f"R² Score: {r2:.4f}")

#MAE shows average error in the same units.
#RMSE penalizes large errors more heavily.
#R² Score shows how much variance in duration is explained by the model
#   (1.0 is perfect, 0.0 means "as good as mean", negative means worse).
# Out:
# MAE: 7.46 minutes
# RMSE: 98.25 minutes
# R² Score: 0.0509

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.3)
plt.xlabel("Actual Duration (min)")
plt.ylabel("Predicted Duration (min)")
plt.title("Actual vs Predicted Duration")
plt.plot([0, 120], [0, 120], 'r--', linewidth=2)
plt.grid(True)
plt.tight_layout()
plt.show()
